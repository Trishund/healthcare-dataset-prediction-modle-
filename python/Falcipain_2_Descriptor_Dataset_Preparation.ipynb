# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
pip install padelpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 37.1 MB/s eta 0:00:00
# ...

# %%
! unzip /content/PaDEL-Descriptor.zip
# Out:
# Archive:  /content/PaDEL-Descriptor.zip
#   inflating: Descriptors.xls
#   inflating: descriptors.xml
#    creating: lib/
#   inflating: lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: lib/appframework-1.0.3.jar
#   inflating: lib/cdk-1.4.15.jar
#   inflating: lib/commons-cli-1.2.jar
#   inflating: lib/guava-17.0.jar
#   inflating: lib/jama.jar
#   inflating: lib/jgrapht-0.6.0.jar
#   inflating: lib/l2fprod-common-all.jar
#   inflating: lib/libPaDEL-Descriptor.jar
#   inflating: lib/libPaDEL-Jobs.jar
#   inflating: lib/libPaDEL.jar
#   inflating: lib/swing-worker-1.1.jar
#   inflating: lib/vecmath1.2-1.14.jar
#   inflating: lib/xom-1.1.jar
#    creating: license/
#   inflating: license/lgpl-2.1.txt
#   inflating: license/lgpl.license
#   inflating: license/LICENSE.txt
#   inflating: license/README - CDK
#   inflating: PaDEL-Descriptor.jar

# %%
! unzip results.zip
# Out:
# Archive:  results.zip
#   inflating: plot_bioactivity_class.pdf
#   inflating: plot_MW_vs_LogP.pdf
#   inflating: mannwhitneyu_pIC50.csv
#   inflating: plot_ic50.pdf
#   inflating: mannwhitneyu_NumHDonors.csv
#   inflating: mannwhitneyu_LogP.csv
#   inflating: mannwhitneyu_MW.csv
#   inflating: plot_LogP.pdf
#   inflating: plot_MW.pdf
#   inflating: plot_NumHDonors.pdf
#   inflating: plot_NumHAcceptors.pdf
#   inflating: bioactivity_preprocessed_data.csv
#   inflating: mannwhitneyu_NumHAcceptors.csv

# %%
import pandas as pd

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **bioactivity_data_3class_pIC50.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
df3 = pd.read_csv('/content/flacipain_2_04_bioactivity_data_3class_pIC50.csv')

# %%
df3
# Out:
#      Unnamed: 0 molecule_chembl_id  \
# 0             0       CHEMBL119345
# 1             1       CHEMBL120254
# 2             2       CHEMBL120076
# 3             3       CHEMBL333067
# 4             4       CHEMBL118210
# ..          ...                ...
# 427         427      CHEMBL5624786
# 428         428      CHEMBL5630854
# 429         429      CHEMBL5630121
# 430         430      CHEMBL5624599
# 431         431      CHEMBL1458713
#
#                                       canonical_smiles       MW     LogP  \
# 0                    Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1  234.284  3.13019
# 1         NC(=S)/N=N/c1c(O)[nH]c2ccc([N+](=O)[O-])cc12  265.254  2.10900
# 2               COc1cccc(CN2C(=O)C(=O)c3cc(Cl)ccc32)c1  301.729  3.07810
# 3               O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccc(Cl)cc21  306.148  3.72290
# 4                 Cc1cc(C)c2[nH]c(O)c(/N=N/C(=N)S)c2c1  248.311  3.43861
# ..                                                 ...      ...      ...
# ...

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1	CHEMBL119345
# NC(=S)/N=N/c1c(O)[nH]c2ccc([N+](=O)[O-])cc12	CHEMBL120254
# COc1cccc(CN2C(=O)C(=O)c3cc(Cl)ccc32)c1	CHEMBL120076
# O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccc(Cl)cc21	CHEMBL333067
# Cc1cc(C)c2[nH]c(O)c(/N=N/C(=N)S)c2c1	CHEMBL118210

# %%
! cat molecule.smi | wc -l
# Out:
# 432

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat /content/padel.sh
# Out:
# #!/bin/bash
#
# # Run PaDEL-Descriptor with your required settings
#
# java -Xms1G -Xmx1G -Djava.awt.headless=true \
#   -jar ./padel-descriptor/PaDEL-Descriptor.jar \
#   -removesalt \
#   -standardizenitro \
#   -fingerprints \
#   -descriptortypes ./padel-descriptor/PubChemFingerprinter.xml \
#   -dir ./ \
#   -file descriptors_output.csv
#
# echo "PaDEL descriptors generated → descriptors_output.csv"

# %%
# !sed -i 's/\r$//' /content/padel.sh

# %%
# !chmod +x /content/padel.sh

# %%
# !mkdir -p padel-descriptor
# !mv /content/PaDEL-Descriptor.jar /content/padel-descriptor/

# %%
! unzip fingerprints_xml\ \(1\).zip
# Out:
# Archive:  fingerprints_xml (1).zip
#   inflating: AtomPairs2DFingerprintCount.xml
#   inflating: AtomPairs2DFingerprinter.xml
#   inflating: EStateFingerprinter.xml
#   inflating: ExtendedFingerprinter.xml
#   inflating: Fingerprinter.xml
#   inflating: GraphOnlyFingerprinter.xml
#   inflating: KlekotaRothFingerprintCount.xml
#   inflating: KlekotaRothFingerprinter.xml
#   inflating: MACCSFingerprinter.xml
#   inflating: PubchemFingerprinter.xml
#   inflating: SubstructureFingerprintCount.xml
#   inflating: SubstructureFingerprinter.xml

# %%
# !mv /content/PubchemFingerprinter.xml /content/padel-descriptor/PubChemFingerprinter.xml

# %%
! /content/padel.sh
# Out:
# Error: Could not find or load main class padeldescriptor.PaDELDescriptorApp
# Caused by: java.lang.NoClassDefFoundError: org/jdesktop/application/SingleFrameApplication
# PaDEL descriptors generated → descriptors_output.csv

# %%
# !bash padel.sh
# Out:
# Error: Could not find or load main class
# Caused by: java.lang.ClassNotFoundException:
# padel.sh: line 2: -jar: command not found
# padel.sh: line 3: -removesalt: command not found
# padel.sh: line 4: -standardizenitro: command not found
# padel.sh: line 5: -fingerprints: command not found
# padel.sh: line 6: -descriptortypes: command not found
# padel.sh: line 7: -dir: command not found
# padel.sh: line 8: -file: command not found
# padel.sh: line 9: $'\r': command not found
# PaDEL descriptors generated → descriptors_output.csv

# %%
! ls -l
# Out:
# total 34296
# -rw-r--r-- 1 root root   655414 Jun  9 17:00 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 root root  8356701 Jun  9 17:08 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Jun  9 17:00 __MACOSX
# -rw-r--r-- 1 root root   310658 Jun  9 17:01 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30 10:10 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Jun  9 16:58 padel.sh
# -rw-r--r-- 1 root root 25768637 Jun  9 16:58 padel.zip
# drwxr-xr-x 1 root root     4096 May 29 18:19 sample_data

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL336398           1  ...             0             0
# 1      CHEMBL133897           1  ...             0             0
# 2      CHEMBL130628           1  ...             0             0
# 3      CHEMBL131588           1  ...             0             0
# 4      CHEMBL130478           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 4690  CHEMBL4293155           1  ...             0             0
# 4691  CHEMBL4282558           1  ...             0             0
# 4692  CHEMBL4281727           1  ...             0             0
# 4693  CHEMBL4292349           1  ...             0             0
# 4694  CHEMBL4278260           1  ...             0             0
#
# [4695 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 4690           1           1  ...             0             0
# 4691           1           1  ...             0             0
# 4692           1           1  ...             0             0
# 4693           1           1  ...             0             0
# 4694           1           1  ...             0             0
#
# [4695 rows x 881 columns]

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           1  ...             0             0  4.301030
# 3              1           1           0  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 4690           1           1           1  ...             0             0  5.612610
# 4691           1           1           1  ...             0             0  5.595166
# 4692           1           1           1  ...             0             0  5.419075
# 4693           1           1           1  ...             0             0  5.460924
# ...

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %% [markdown]
# # **Let's download the CSV file to your local computer for the Part 3B (Model Building).**
