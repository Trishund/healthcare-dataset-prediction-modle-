# %% [markdown]
# <a href="https://colab.research.google.com/github/Trishund/healthcare-dataset-prediction-modle-/blob/main/python/CDD_ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.11.12)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.7 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.9 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for malarial drug repurposing**

# %%
# Target search for malarial drug repurposing
target = new_client.target
target_query = target.search('falcipain')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                   organism  \
# 0               []      Plasmodium falciparum
# 1               []      Plasmodium falciparum
# 2               []  Plasmodium falciparum 3D7
# 3               []      Plasmodium falciparum
# 4               []      Plasmodium falciparum
# 5               []      Plasmodium falciparum
# 6               []      Plasmodium falciparum
# 7               []  Plasmodium falciparum 3D7
#
#                          pref_name  score  species_group_flag  \
# 0                      Falcipain 2   20.0               False
# 1    Cysteine protease falcipain-2   19.0               False
# 2                      Falcipain-3   19.0               False
# 3    Cysteine protease falcipain-3   18.0               False
# 4                     Falcipain 2B   18.0               False
# 5                      Falcipain 2   18.0               False
# 6    Cysteine protease falcipain-3   18.0               False
# 7  Cysteine proteinase falcipain-1   17.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL1697672  [{'accession': 'Q9NAW2', 'component_descriptio...
# 1       CHEMBL5801  [{'accession': 'Q9NBD4', 'component_descriptio...
# 2    CHEMBL1250373  [{'accession': 'Q8IIL0', 'component_descriptio...
# 3       CHEMBL4510  [{'accession': 'Q9NBA7', 'component_descriptio...
# 4       CHEMBL3488  [{'accession': 'Q3HTL5', 'component_descriptio...
# 5       CHEMBL5800  [{'accession': 'Q9N6S8', 'component_descriptio...
# 6    CHEMBL1697661  [{'accession': 'Q9NAW4', 'component_descriptio...
# 7    CHEMBL1250371  [{'accession': 'Q8I6V0', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN    5833
# 1  SINGLE PROTEIN    5833
# 2  SINGLE PROTEIN   36329
# 3  SINGLE PROTEIN    5833
# 4  SINGLE PROTEIN    5833
# 5  SINGLE PROTEIN    5833
# 6  SINGLE PROTEIN    5833
# 7  SINGLE PROTEIN   36329

# %% [markdown]
# ### **Select and retrieve bioactivity data for *falcipain 2* (sixth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *falcipain 2* ) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL5800'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *falcipain 2* (CHEMBL5800) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None       Not Active
# 1                                                 None       Not Active
# 2                                                 None       Not Active
# 3                                                 None       Not Active
# 4                                                 None       Not Active
# ..                                                 ...              ...
# 467  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 468  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 469  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 470  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 471  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 0         553640                                                 []
# 1         554837                                                 []
# 2         554840                                                 []
# 3         555983                                                 []
# 4         555986                                                 []
# ..           ...                                                ...
# 467     26139210  [{'comments': None, 'relation': '=', 'result_f...
# 468     26139211  [{'comments': None, 'relation': '=', 'result_f...
# 469     26139212  [{'comments': None, 'relation': '=', 'result_f...
# 470     26139213  [{'comments': None, 'relation': '=', 'result_f...
# 471     26139214  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL682030  Inhibitory activity against Falcipain-2; no ef...
# 1      CHEMBL682029  Inhibitory activity against Falcipain-2; No ef...
# 2      CHEMBL682029  Inhibitory activity against Falcipain-2; No ef...
# 3      CHEMBL682030  Inhibitory activity against Falcipain-2; no ef...
# 4      CHEMBL682030  Inhibitory activity against Falcipain-2; no ef...
# ..              ...                                                ...
# 467   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 468   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 469   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 470   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 471   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 467          B                    None                   None  BAO_0000190
# 468          B                    None                   None  BAO_0000190
# 469          B                    None                   None  BAO_0000190
# 470          B                    None                   None  BAO_0000190
# 471          B                    None                   None  BAO_0000190
#
#      ...        target_organism target_pref_name target_tax_id text_value  \
# 0    ...  Plasmodium falciparum      Falcipain 2          5833       None
# 1    ...  Plasmodium falciparum      Falcipain 2          5833       None
# 2    ...  Plasmodium falciparum      Falcipain 2          5833       None
# 3    ...  Plasmodium falciparum      Falcipain 2          5833       None
# 4    ...  Plasmodium falciparum      Falcipain 2          5833       None
# ..   ...                    ...              ...           ...        ...
# 467  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 468  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 469  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 470  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 471  ...  Plasmodium falciparum      Falcipain 2          5833       None
#
#      toid  type units    uo_units upper_value value
# 0    None  IC50    uM  UO_0000065        None  None
# 1    None  IC50    uM  UO_0000065        None  None
# 2    None  IC50    uM  UO_0000065        None  None
# 3    None  IC50    uM  UO_0000065        None  None
# 4    None  IC50    uM  UO_0000065        None  None
# ..    ...   ...   ...         ...         ...   ...
# 467  None  IC50    uM  UO_0000065        None   7.1
# 468  None  IC50    uM  UO_0000065        None  10.4
# 469  None  IC50    uM  UO_0000065        None   5.4
# 470  None  IC50    uM  UO_0000065        None   4.6
# 471  None  IC50    uM  UO_0000065        None  54.4
#
# [472 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
df[["action_type", "assay_chembl_id", "standard_type", "standard_value"]]
# Out:
#                                            action_type assay_chembl_id  \
# 0                                                 None    CHEMBL682030
# 1                                                 None    CHEMBL682029
# 2                                                 None    CHEMBL682029
# 3                                                 None    CHEMBL682030
# 4                                                 None    CHEMBL682030
# ..                                                 ...             ...
# 467  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5622194
# 468  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5622194
# 469  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5622194
# 470  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5622194
# 471  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5622194
#
#     standard_type standard_value
# 0            IC50           None
# 1            IC50           None
# 2            IC50           None
# 3            IC50           None
# 4            IC50           None
# ..            ...            ...
# 467          IC50         7100.0
# 468          IC50        10400.0
# 469          IC50         5400.0
# 470          IC50         4600.0
# 471          IC50        54400.0
#
# [472 rows x 4 columns]

# %%
df = df.dropna(subset=["standard_value"])
df["standard_value"] = pd.to_numeric(df["standard_value"])

lowest3 = df.nsmallest(450, "standard_value")[[
    "action_type",
    "assay_chembl_id",
    "standard_type",
    "standard_value"
]]

lowest3
# Out:
# /tmp/ipython-input-2530081764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["standard_value"] = pd.to_numeric(df["standard_value"])
#                                            action_type assay_chembl_id  \
# 446  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5326422
# 448  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5326422
# 363                                               None   CHEMBL4223220
# 339                                               None   CHEMBL4223220
# 187                                               None    CHEMBL945401
# ..                                                 ...             ...
# 198                                               None   CHEMBL1074166
# 197                                               None   CHEMBL1074166
# 406                                               None   CHEMBL5326394
# 413  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5326396
# 440  {'action_type': 'INHIBITOR', 'description': 'N...   CHEMBL5326402
#
#     standard_type  standard_value
# 446          IC50            0.36
# 448          IC50            0.42
# 363          IC50            0.60
# 339          IC50            1.20
# 187          IC50            2.00
# ..            ...             ...
# 198          IC50       100000.00
# 197          IC50       100000.00
# 406          IC50       100000.00
# 413          IC50       107320.00
# 440          IC50       110000.00
#
# [432 rows x 4 columns]

# %%
df.to_csv('ascending_standard_values.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! cp ascending_standard_values.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# total 519
# -rw------- 1 root root 257070 Dec  2 11:38 ascending_standard_values.csv
# -rw------- 1 root root 273141 Dec  2 11:38 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# ascending_standard_values.csv  bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,Not Active,553640,[],CHEMBL682030,Inhibitory activity against Falcipain-2; no effect,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(C(=O)OCc2ccccc2)c2ccccc21,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL119515,,CHEMBL119515,,0,http://www.openphacts.org/units/Nanomolar,223841,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Active,554837,[],CHEMBL682029,Inhibitory activity against Falcipain-2; No effect,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1Nc2ccccc2C1=O,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL326294,ISATIN,CHEMBL326294,,0,http://www.openphacts.org/units/Nanomolar,223820,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Active,554840,[],CHEMBL682029,Inhibitory activity against Falcipain-2; No effect,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1ccc2c(c1)C(=O)C(=O)N2,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL118883,,CHEMBL118883,,0,http://www.openphacts.org/units/Nanomolar,223849,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Active,555983,[],CHEMBL682030,Inhibitory activity against Falcipain-2; no effect,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(S(=O)(=O)c2ccccc2)c2ccccc21,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL119828,,CHEMBL119828,,0,http://www.openphacts.org/units/Nanomolar,223843,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Active,555986,[],CHEMBL682030,Inhibitory activity against Falcipain-2; no effect,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1ccc(C)c(CN2C(=O)C(=O)c3cc(C)ccc32)c1,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL118638,,CHEMBL118638,,0,http://www.openphacts.org/units/Nanomolar,223840,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,,557287,[],CHEMBL682028,Inhibitory activity against Falcipain-2,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,"{'bei': '18.60', 'le': '0.37', 'lle': '1.23', 'sei': '5.15'}",CHEMBL119345,,CHEMBL119345,4.36,0,http://www.openphacts.org/units/Nanomolar,223828,=,1,1,=,,IC50,nM,,43900.0,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,43.9
# ,Not Active,557290,[],CHEMBL682030,Inhibitory activity against Falcipain-2; no effect,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(c2ccccc2)c2ccccc21,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL117447,PHENYL ISATIN,CHEMBL117447,,0,http://www.openphacts.org/units/Nanomolar,223845,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Active,557293,[],CHEMBL682030,Inhibitory activity against Falcipain-2; no effect,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(C(=O)OCc2ccccc2)c2ccc(Cl)cc21,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL326185,,CHEMBL326185,,0,http://www.openphacts.org/units/Nanomolar,223833,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,
# ,Not Determined,557296,[],CHEMBL877815,Inhibitory activity against Falcipain-2; not determined,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(C(=O)OCc2ccccc2)c2ccc(F)cc21,,,CHEMBL1145878,Bioorg Med Chem Lett,2003,,CHEMBL118762,,CHEMBL118762,,0,http://www.openphacts.org/units/Nanomolar,223831,,1,0,,,IC50,nM,,,CHEMBL5800,Plasmodium falciparum,Falcipain 2,5833,,,IC50,uM,UO_0000065,,

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 5                                                 None             None
# 11                                                None             None
# 14                                                None             None
# 16                                                None             None
# 17                                                None             None
# ..                                                 ...              ...
# 467  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 468  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 469  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 470  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 471  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 5         557287                                                 []
# 11        559694                                                 []
# 14        565365                                                 []
# 16        569132                                                 []
# 17        570441                                                 []
# ..           ...                                                ...
# 467     26139210  [{'comments': None, 'relation': '=', 'result_f...
# 468     26139211  [{'comments': None, 'relation': '=', 'result_f...
# 469     26139212  [{'comments': None, 'relation': '=', 'result_f...
# 470     26139213  [{'comments': None, 'relation': '=', 'result_f...
# 471     26139214  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 5      CHEMBL682028            Inhibitory activity against Falcipain-2
# 11     CHEMBL682028            Inhibitory activity against Falcipain-2
# 14     CHEMBL682028            Inhibitory activity against Falcipain-2
# 16     CHEMBL682028            Inhibitory activity against Falcipain-2
# 17     CHEMBL682028            Inhibitory activity against Falcipain-2
# ..              ...                                                ...
# 467   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 468   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 469   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 470   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
# 471   CHEMBL5622194  Inhibition of Plasmodium falciparum FP2 using ...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 5            B                    None                   None  BAO_0000190
# 11           B                    None                   None  BAO_0000190
# 14           B                    None                   None  BAO_0000190
# 16           B                    None                   None  BAO_0000190
# 17           B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 467          B                    None                   None  BAO_0000190
# 468          B                    None                   None  BAO_0000190
# 469          B                    None                   None  BAO_0000190
# 470          B                    None                   None  BAO_0000190
# 471          B                    None                   None  BAO_0000190
#
#      ...        target_organism target_pref_name target_tax_id text_value  \
# 5    ...  Plasmodium falciparum      Falcipain 2          5833       None
# 11   ...  Plasmodium falciparum      Falcipain 2          5833       None
# 14   ...  Plasmodium falciparum      Falcipain 2          5833       None
# 16   ...  Plasmodium falciparum      Falcipain 2          5833       None
# 17   ...  Plasmodium falciparum      Falcipain 2          5833       None
# ..   ...                    ...              ...           ...        ...
# 467  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 468  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 469  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 470  ...  Plasmodium falciparum      Falcipain 2          5833       None
# 471  ...  Plasmodium falciparum      Falcipain 2          5833       None
#
#      toid  type units    uo_units upper_value value
# 5    None  IC50    uM  UO_0000065        None  43.9
# 11   None  IC50    uM  UO_0000065        None   4.4
# 14   None  IC50    uM  UO_0000065        None  34.6
# 16   None  IC50    uM  UO_0000065        None  31.2
# 17   None  IC50    uM  UO_0000065        None  13.2
# ..    ...   ...   ...         ...         ...   ...
# 467  None  IC50    uM  UO_0000065        None   7.1
# 468  None  IC50    uM  UO_0000065        None  10.4
# 469  None  IC50    uM  UO_0000065        None   5.4
# 470  None  IC50    uM  UO_0000065        None   4.6
# 471  None  IC50    uM  UO_0000065        None  54.4
#
# [432 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
df2.molecule_chembl_id
# Out:
# 5       CHEMBL119345
# 11      CHEMBL120254
# 14      CHEMBL120076
# 16      CHEMBL333067
# 17      CHEMBL118210
#            ...
# 467    CHEMBL5624786
# 468    CHEMBL5630854
# 469    CHEMBL5630121
# 470    CHEMBL5624599
# 471    CHEMBL1458713
# Name: molecule_chembl_id, Length: 432, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL119345',
#  'CHEMBL120254',
#  'CHEMBL120076',
#  'CHEMBL333067',
#  'CHEMBL118210',
#  'CHEMBL324722',
#  'CHEMBL119213',
#  'CHEMBL118355',
#  'CHEMBL336693',
#  'CHEMBL418861',
#  'CHEMBL118305',
#  'CHEMBL117767',
#  'CHEMBL333137',
#  'CHEMBL119370',
#  'CHEMBL119756',
#  'CHEMBL414179',
#  'CHEMBL90748',
#  'CHEMBL93881',
#  'CHEMBL420812',
#  'CHEMBL92805',
#  'CHEMBL91233',
#  'CHEMBL329337',
#  'CHEMBL89985',
#  'CHEMBL92872',
#  'CHEMBL91234',
#  'CHEMBL93694',
#  'CHEMBL92683',
#  'CHEMBL329629',
#  'CHEMBL328100',
#  'CHEMBL90245',
#  'CHEMBL92995',
#  'CHEMBL433390',
#  'CHEMBL92738',
#  'CHEMBL93846',
#  'CHEMBL93466',
#  'CHEMBL91049',
#  'CHEMBL92956',
#  'CHEMBL91050',
#  'CHEMBL329532',
#  'CHEMBL93465',
#  'CHEMBL91856',
#  'CHEMBL93341',
#  'CHEMBL326220',
#  'CHEMBL73007',
#  'CHEMBL107612',
#  'CHEMBL323975',
#  'CHEMBL416771',
#  'CHEMBL325549',
#  'CHEMBL181504',
#  'CHEMBL181902',
#  'CHEMBL181752',
#  'CHEMBL183767',
#  'CHEMBL182795',
#  'CHEMBL183396',
#  'CHEMBL182790',
#  'CHEMBL183005',
#  'CHEMBL195381',
#  'CHEMBL194821',
#  'CHEMBL195822',
#  'CHEMBL191640',
#  'CHEMBL192149',
#  'CHEMBL191457',
#  'CHEMBL373022',
#  'CHEMBL370877',
#  'CHEMBL191881',
#  'CHEMBL374508',
#  'CHEMBL381093',
#  'CHEMBL374508',
#  'CHEMBL204973',
#  'CHEMBL204850',
#  'CHEMBL204452',
#  'CHEMBL380140',
#  'CHEMBL383231',
#  'CHEMBL203856',
#  'CHEMBL203823',
#  'CHEMBL204344',
#  'CHEMBL203802',
#  'CHEMBL203801',
#  'CHEMBL382027',
#  'CHEMBL379228',
#  'CHEMBL204491',
#  'CHEMBL205056',
#  'CHEMBL440764',
#  'CHEMBL204035',
#  'CHEMBL203649',
#  'CHEMBL377557',
#  'CHEMBL423112',
#  'CHEMBL210211',
#  'CHEMBL378223',
#  'CHEMBL209147',
#  'CHEMBL437308',
#  'CHEMBL382121',
#  'CHEMBL378475',
#  'CHEMBL207102',
#  'CHEMBL207117',
#  'CHEMBL377886',
#  'CHEMBL379633',
#  'CHEMBL211516',
#  'CHEMBL379148',
#  'CHEMBL213961',
#  'CHEMBL213827',
#  'CHEMBL224801',
#  'CHEMBL222709',
#  'CHEMBL221471',
#  'CHEMBL222708',
#  'CHEMBL222707',
#  'CHEMBL222706',
#  'CHEMBL376232',
#  'CHEMBL224916',
#  'CHEMBL224915',
#  'CHEMBL222270',
#  'CHEMBL373909',
#  'CHEMBL374367',
#  'CHEMBL374510',
#  'CHEMBL426564',
#  'CHEMBL224858',
#  'CHEMBL224803',
#  'CHEMBL221833',
#  'CHEMBL438659',
#  'CHEMBL221991',
#  'CHEMBL436500',
#  'CHEMBL222325',
#  'CHEMBL222322',
#  'CHEMBL222871',
#  'CHEMBL222870',
#  'CHEMBL374508',
#  'CHEMBL224891',
#  'CHEMBL224258',
#  'CHEMBL387974',
#  'CHEMBL225644',
#  'CHEMBL225592',
#  'CHEMBL388317',
#  'CHEMBL427253',
#  'CHEMBL388101',
#  'CHEMBL224260',
#  'CHEMBL387860',
#  'CHEMBL389869',
#  'CHEMBL225323',
#  'CHEMBL224893',
#  'CHEMBL225646',
#  'CHEMBL225184',
#  'CHEMBL224312',
#  'CHEMBL225449',
#  'CHEMBL223654',
#  'CHEMBL434743',
#  'CHEMBL224025',
#  'CHEMBL398828',
#  'CHEMBL250154',
#  'CHEMBL250155',
#  'CHEMBL399032',
#  'CHEMBL378223',
#  'CHEMBL272015',
#  'CHEMBL403991',
#  'CHEMBL402455',
#  'CHEMBL405741',
#  'CHEMBL407354',
#  'CHEMBL270278',
#  'CHEMBL408071',
#  'CHEMBL271992',
#  'CHEMBL488829',
#  'CHEMBL486232',
#  'CHEMBL487275',
#  'CHEMBL374508',
#  'CHEMBL592303',
#  'CHEMBL592268',
#  'CHEMBL606235',
#  'CHEMBL589904',
#  'CHEMBL589903',
#  'CHEMBL596611',
#  'CHEMBL596610',
#  'CHEMBL597220',
#  'CHEMBL597219',
#  'CHEMBL597017',
#  'CHEMBL602103',
#  'CHEMBL589510',
#  'CHEMBL597626',
#  'CHEMBL597625',
#  'CHEMBL597624',
#  'CHEMBL597896',
#  'CHEMBL589509',
#  'CHEMBL597892',
#  'CHEMBL191881',
#  'CHEMBL191881',
#  'CHEMBL1689606',
#  'CHEMBL1689610',
#  'CHEMBL1689611',
#  'CHEMBL1689604',
#  'CHEMBL1689605',
#  'CHEMBL1689609',
#  'CHEMBL374508',
#  'CHEMBL1689595',
#  'CHEMBL1689596',
#  'CHEMBL1689597',
#  'CHEMBL1689598',
#  'CHEMBL1689599',
#  'CHEMBL1689600',
#  'CHEMBL1689601',
#  'CHEMBL1689594',
#  'CHEMBL1689602',
#  'CHEMBL1689603',
#  'CHEMBL1689607',
#  'CHEMBL1689608',
#  'CHEMBL1687962',
#  'CHEMBL1689612',
#  'CHEMBL1689613',
#  'CHEMBL1689614',
#  'CHEMBL1689615',
#  'CHEMBL374508',
#  'CHEMBL2235041',
#  'CHEMBL2235040',
#  'CHEMBL2235039',
#  'CHEMBL2235038',
#  'CHEMBL2235037',
#  'CHEMBL2235036',
#  'CHEMBL2235035',
#  'CHEMBL2235034',
#  'CHEMBL2235033',
#  'CHEMBL2235032',
#  'CHEMBL2235031',
#  'CHEMBL2235030',
#  'CHEMBL2235029',
#  'CHEMBL2235028',
#  'CHEMBL2260636',
#  'CHEMBL2260635',
#  'CHEMBL2260634',
#  'CHEMBL2260632',
#  'CHEMBL2260631',
#  'CHEMBL2260630',
#  'CHEMBL2260629',
#  'CHEMBL2260628',
#  'CHEMBL2260636',
#  'CHEMBL2260635',
#  'CHEMBL2260634',
#  'CHEMBL2260632',
#  'CHEMBL2260631',
#  'CHEMBL2260630',
#  'CHEMBL2260629',
#  'CHEMBL2260628',
#  'CHEMBL3120850',
#  'CHEMBL3120849',
#  'CHEMBL3120848',
#  'CHEMBL3120847',
#  'CHEMBL3120846',
#  'CHEMBL3120844',
#  'CHEMBL3120845',
#  'CHEMBL3120843',
#  'CHEMBL3120842',
#  'CHEMBL3120840',
#  'CHEMBL3120841',
#  'CHEMBL3120839',
#  'CHEMBL3120838',
#  'CHEMBL3120836',
#  'CHEMBL3120837',
#  'CHEMBL3120835',
#  'CHEMBL3120834',
#  'CHEMBL3120832',
#  'CHEMBL3120833',
#  'CHEMBL3120831',
#  'CHEMBL3120829',
#  'CHEMBL3120830',
#  'CHEMBL3352874',
#  'CHEMBL3358144',
#  'CHEMBL3358143',
#  'CHEMBL3358142',
#  'CHEMBL3358141',
#  'CHEMBL3358140',
#  'CHEMBL3358139',
#  'CHEMBL3358138',
#  'CHEMBL3358137',
#  'CHEMBL3358136',
#  'CHEMBL3358135',
#  'CHEMBL3358134',
#  'CHEMBL3358133',
#  'CHEMBL3358132',
#  'CHEMBL3358131',
#  'CHEMBL3358130',
#  'CHEMBL3358129',
#  'CHEMBL3358128',
#  'CHEMBL541700',
#  'CHEMBL541700',
#  'CHEMBL4101714',
#  'CHEMBL4100751',
#  'CHEMBL4082758',
#  'CHEMBL4093034',
#  'CHEMBL4072275',
#  'CHEMBL4096388',
#  'CHEMBL4078345',
#  'CHEMBL4062015',
#  'CHEMBL4083754',
#  'CHEMBL4070637',
#  'CHEMBL2402204',
#  'CHEMBL4081250',
#  'CHEMBL4099269',
#  'CHEMBL4090306',
#  'CHEMBL4060936',
#  'CHEMBL4074432',
#  'CHEMBL374508',
#  'CHEMBL2235031',
#  'CHEMBL4227848',
#  'CHEMBL4227031',
#  'CHEMBL4227486',
#  'CHEMBL4226307',
#  'CHEMBL4227166',
#  'CHEMBL4226577',
#  'CHEMBL4227427',
#  'CHEMBL4224764',
#  'CHEMBL4227696',
#  'CHEMBL4225350',
#  'CHEMBL4227965',
#  'CHEMBL4228920',
#  'CHEMBL4228081',
#  'CHEMBL4229174',
#  'CHEMBL4228343',
#  'CHEMBL4224829',
#  'CHEMBL4228604',
#  'CHEMBL4225099',
#  'CHEMBL4228861',
#  'CHEMBL4225367',
#  'CHEMBL4228800',
#  'CHEMBL4226767',
#  'CHEMBL4227619',
#  'CHEMBL4227566',
#  'CHEMBL4228399',
#  'CHEMBL4227295',
#  'CHEMBL4228143',
#  'CHEMBL1215628',
#  'CHEMBL4228926',
#  'CHEMBL4516951',
#  'CHEMBL4456644',
#  'CHEMBL4439637',
#  'CHEMBL1458713',
#  'CHEMBL4472824',
#  'CHEMBL4467013',
#  'CHEMBL4434685',
#  'CHEMBL4564002',
#  'CHEMBL4442854',
#  'CHEMBL4473513',
#  'CHEMBL4594166',
#  'CHEMBL4475837',
#  'CHEMBL4437416',
#  'CHEMBL4555968',
#  'CHEMBL4527228',
#  'CHEMBL4562998',
#  'CHEMBL4555310',
#  'CHEMBL4442674',
#  'CHEMBL1302947',
#  'CHEMBL4451728',
#  'CHEMBL4582464',
#  'CHEMBL4449400',
#  'CHEMBL4582597',
#  'CHEMBL4578038',
#  'CHEMBL4458321',
#  'CHEMBL4551614',
#  'CHEMBL1584095',
#  'CHEMBL4444541',
#  'CHEMBL4471644',
#  'CHEMBL4646055',
#  'CHEMBL4637201',
#  'CHEMBL327624',
#  'CHEMBL486232',
#  'CHEMBL5411543',
#  'CHEMBL5420328',
#  'CHEMBL5419296',
#  'CHEMBL5397408',
#  'CHEMBL5420093',
#  'CHEMBL541700',
#  'CHEMBL1213751',
#  'CHEMBL5424800',
#  'CHEMBL5416707',
#  'CHEMBL5404412',
#  'CHEMBL5406869',
#  'CHEMBL5399441',
#  'CHEMBL5402350',
#  'CHEMBL5417979',
#  'CHEMBL5394920',
#  'CHEMBL5395393',
#  'CHEMBL5439062',
#  'CHEMBL5425369',
#  'CHEMBL5398030',
#  'CHEMBL5412407',
#  'CHEMBL5437576',
#  'CHEMBL5408566',
#  'CHEMBL5420035',
#  'CHEMBL5438601',
#  'CHEMBL5400936',
#  'CHEMBL5436591',
#  'CHEMBL5394407',
#  'CHEMBL5420927',
#  'CHEMBL5411995',
#  'CHEMBL5426937',
#  'CHEMBL5411313',
#  'CHEMBL5428518',
#  'CHEMBL5398031',
#  'CHEMBL5434197',
#  'CHEMBL5404235',
#  'CHEMBL5424376',
#  'CHEMBL5419333',
#  'CHEMBL559434',
#  'CHEMBL5426764',
#  'CHEMBL5421969',
#  'CHEMBL5436386',
#  'CHEMBL5440402',
#  'CHEMBL5420344',
#  'CHEMBL5424180',
#  'CHEMBL4215216',
#  'CHEMBL5409393',
#  'CHEMBL5437384',
#  'CHEMBL5407224',
#  'CHEMBL5398692',
#  'CHEMBL5438396',
#  'CHEMBL5416078',
#  'CHEMBL5394154',
#  'CHEMBL5422873',
#  'CHEMBL5437766',
#  'CHEMBL5398485',
#  'CHEMBL5395561',
#  'CHEMBL5434874',
#  'CHEMBL5400091',
#  'CHEMBL374508',
#  'CHEMBL5406869',
#  'CHEMBL5424800',
#  'CHEMBL5556412',
#  'CHEMBL5563817',
#  'CHEMBL5625072',
#  'CHEMBL5630622',
#  'CHEMBL5630614',
#  'CHEMBL5630817',
#  'CHEMBL5624786',
#  'CHEMBL5630854',
#  'CHEMBL5630121',
#  'CHEMBL5624599',
#  'CHEMBL1458713']

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL119345                  Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1
# 1         CHEMBL120254       NC(=S)/N=N/c1c(O)[nH]c2ccc([N+](=O)[O-])cc12
# 2         CHEMBL120076             COc1cccc(CN2C(=O)C(=O)c3cc(Cl)ccc32)c1
# 3         CHEMBL333067             O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccc(Cl)cc21
# 4         CHEMBL118210               Cc1cc(C)c2[nH]c(O)c(/N=N/C(=N)S)c2c1
# ..                 ...                                                ...
# 427      CHEMBL5624786  COc1ccc(C(c2cccc(OC)c2O)N2CCN(c3ccnc4cc(Cl)ccc...
# 428      CHEMBL5630854  COc1cccc(C(c2ccc(F)c(F)c2)N2CCN(c3ccnc4cc(Cl)c...
# 429      CHEMBL5630121  COc1cccc(C(c2ccc(C(F)(F)F)cc2)N2CCN(c3ccnc4cc(...
# 430      CHEMBL5624599  COc1cccc(C(c2ccc(Cl)c(Cl)c2)N2CCN(c3ccnc4cc(Cl...
# 431      CHEMBL1458713  CC(C)C[C@H](NC(=O)[C@@H]1O[C@H]1C(=O)O)C(=O)NC...
#
#     bioactivity_class  standard_value
# 0            inactive         43900.0
# 1        intermediate          4400.0
# 2            inactive         34600.0
# 3            inactive         31200.0
# 4            inactive         13200.0
# ..                ...             ...
# 427      intermediate          7100.0
# 428          inactive         10400.0
# 429      intermediate          5400.0
# 430      intermediate          4600.0
# 431          inactive         54400.0
#
# [432 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 5         CHEMBL119345                  Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1
# 11        CHEMBL120254       NC(=S)/N=N/c1c(O)[nH]c2ccc([N+](=O)[O-])cc12
# 14        CHEMBL120076             COc1cccc(CN2C(=O)C(=O)c3cc(Cl)ccc32)c1
# 16        CHEMBL333067             O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccc(Cl)cc21
# 17        CHEMBL118210               Cc1cc(C)c2[nH]c(O)c(/N=N/C(=N)S)c2c1
# ..                 ...                                                ...
# 467      CHEMBL5624786  COc1ccc(C(c2cccc(OC)c2O)N2CCN(c3ccnc4cc(Cl)ccc...
# 468      CHEMBL5630854  COc1cccc(C(c2ccc(F)c(F)c2)N2CCN(c3ccnc4cc(Cl)c...
# 469      CHEMBL5630121  COc1cccc(C(c2ccc(C(F)(F)F)cc2)N2CCN(c3ccnc4cc(...
# 470      CHEMBL5624599  COc1cccc(C(c2ccc(Cl)c(Cl)c2)N2CCN(c3ccnc4cc(Cl...
# 471      CHEMBL1458713  CC(C)C[C@H](NC(=O)[C@@H]1O[C@H]1C(=O)O)C(=O)NC...
#
#      standard_value
# 5           43900.0
# 11           4400.0
# 14          34600.0
# 16          31200.0
# 17          13200.0
# ..              ...
# 467          7100.0
# 468         10400.0
# 469          5400.0
# 470          4600.0
# 471         54400.0
#
# [432 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                              canonical_smiles  \
# 5         CHEMBL119345             Cc1ccc2[nH]c(O)c(/N=N/C(=N)S)c2c1
# 11        CHEMBL120254  NC(=S)/N=N/c1c(O)[nH]c2ccc([N+](=O)[O-])cc12
# 14        CHEMBL120076        COc1cccc(CN2C(=O)C(=O)c3cc(Cl)ccc32)c1
# 16        CHEMBL333067        O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccc(Cl)cc21
# 17        CHEMBL118210          Cc1cc(C)c2[nH]c(O)c(/N=N/C(=N)S)c2c1
# ..                 ...                                           ...
# 265                NaN                                           NaN
# 269                NaN                                           NaN
# 275                NaN                                           NaN
# 368                NaN                                           NaN
# 369                NaN                                           NaN
#
#      standard_value             0
# 5           43900.0      inactive
# 11           4400.0  intermediate
# 14          34600.0      inactive
# 16          31200.0      inactive
# 17          13200.0      inactive
# ..              ...           ...
# 265             NaN        active
# 269             NaN  intermediate
# 275             NaN  intermediate
# 368             NaN      inactive
# 369             NaN      inactive
#
# [472 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 564
# -rw-r--r-- 1 root root 257070 Dec  2 11:38 ascending_standard_values.csv
# -rw-r--r-- 1 root root 273141 Dec  2 11:38 bioactivity_data.csv
# -rw-r--r-- 1 root root  36325 Dec  2 11:38 bioactivity_preprocessed_data.csv
# drwx------ 5 root root   4096 Dec  2 11:38 gdrive
# drwxr-xr-x 1 root root   4096 Nov 20 14:30 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# ascending_standard_values.csv  bioactivity_preprocessed_data.csv
# bioactivity_data.csv

# %% [markdown]
# ---
